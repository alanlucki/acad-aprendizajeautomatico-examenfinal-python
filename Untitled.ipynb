# %%
import os
import librosa
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-6f6412980ca9> in <module>
#       1 import os
# ----> 2 import librosa
#       3
#
# ~\anaconda3\envs\jupyter\lib\site-packages\librosa\__init__.py in <module>
#      10 # And all the librosa sub-modules
#      11 from ._cache import cache
# ---> 12 from . import core
#      13 from . import beat
#      14 from . import decompose
#
# ~\anaconda3\envs\jupyter\lib\site-packages\librosa\core\__init__.py in <module>
#     123 """
#     124
# --> 125 from .time_frequency import *  # pylint: disable=wildcard-import
#     126 from .audio import *  # pylint: disable=wildcard-import
#     127 from .spectrum import *  # pylint: disable=wildcard-import
#
# ~\anaconda3\envs\jupyter\lib\site-packages\librosa\core\time_frequency.py in <module>
#      10
#      11 from ..util.exceptions import ParameterError
# ...
